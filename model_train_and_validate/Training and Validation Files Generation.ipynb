# %% [markdown]
# Imports necessary files from other .py notebooks

# %%
from py_files import preprocessing as pp
from py_files import Augmentation as ag
from py_files import pic_class as pc
from py_files import TrainTestSplit as ts
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib agg
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import os
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Runs a preprocessing step in order to graph, then save the files as images.

# %%
pp.preprocessing('Raman_Data')
# Out:
# fluorescent
# nylon
# polyamide
# polyethylene
# unknown

# %% [markdown]
# Augments the preprocessed images so the tensorflow program is able to work off of more datapoints.

# %%
ag.full_augmentation('Pre_Augmented_Raman_Pictures')
# Out:
# 20191004 Set3Sample3_10a 1_.txt_fluorescent.png
# 20191004 Set3Sample3_11 5_.txt_polyethylene.png
# 20191004 Set3Sample3_12 5_.txt_fluorescent.png
# 20191004 Set3Sample3_2 1_.txt_unknown.png
# 20191004 Set3Sample3_4 5_.txt_polyethylene.png
# 20191004 Set3Sample3_5 5_.txt_polyethylene.png
# 20191004 Set3Sample3_6 5_.txt_polyethylene.png
# 20191004 Set3Sample3_7 5_.txt_polyethylene.png
# 20191004 Set3Sample3_8 5_.txt_polyethylene.png
# 20191004 Set3Sample3_9 5_.txt_polyethylene.png
# 20191004 Set7Sample6_10 0.txt_fluorescent.png
# 20191004 Set7Sample6_2 5_.txt_unknown.png
# 20191004 Set7Sample6_4 5_.txt_unknown.png
# 20191004 Set7Sample6_7a 5_.txt_unknown.png
# 20191004 Set7Sample6_8 1_.txt_fluorescent.png
# 20191120 Set2Sample5a-1_.txt_nylon.png
# 20191120 Set2Sample5b-1_.txt_nylon.png
# 20191120 Set2Sample5c-1_.txt_nylon.png
# 20191120 Set2Sample5e-1_.txt_nylon.png
# 20191127 Set2Sample7a_1_.txt_fluorescent.png
# 20191127 Set2Sample7b_0.txt_fluorescent.png
# ...

# %%
source = os.getcwd()

# %%
source1 = source + '/Post_Augmented_Raman_Pictures'

# %%
ts.train_test_split(source1, 0.8)
# Out:
# 020191004 Set3Sample3_10a 1_.txt_fluorescent.png
# 020191004 Set3Sample3_11 5_.txt_polyethylene.png
# 020191004 Set3Sample3_12 5_.txt_fluorescent.png
# 020191004 Set3Sample3_2 1_.txt_unknown.png
# 020191004 Set3Sample3_4 5_.txt_polyethylene.png
# 020191004 Set3Sample3_5 5_.txt_polyethylene.png
# 020191004 Set3Sample3_6 5_.txt_polyethylene.png
# 020191004 Set3Sample3_7 5_.txt_polyethylene.png
# 020191004 Set3Sample3_8 5_.txt_polyethylene.png
# 020191004 Set3Sample3_9 5_.txt_polyethylene.png
# 020191004 Set7Sample6_10 0.txt_fluorescent.png
# 020191004 Set7Sample6_2 5_.txt_unknown.png
# 020191004 Set7Sample6_4 5_.txt_unknown.png
# 020191004 Set7Sample6_7a 5_.txt_unknown.png
# 020191004 Set7Sample6_8 1_.txt_fluorescent.png
# 020191120 Set2Sample5a-1_.txt_nylon.png
# 020191120 Set2Sample5b-1_.txt_nylon.png
# 020191120 Set2Sample5c-1_.txt_nylon.png
# 020191120 Set2Sample5e-1_.txt_nylon.png
# 020191127 Set2Sample7a_1_.txt_fluorescent.png
# 020191127 Set2Sample7b_0.txt_fluorescent.png
# ...

# %%
source2 = source + '/validationdata_Pictures'

# %%
pc.picture_classification(source2)

# %%
source3 = source + '/trainingdata_Pictures'

# %%
pc.picture_classification(source3)
